# %% [markdown]
# # Create the train datastracture for 3 edges

# %%
import pandas as pd

# Specify the features to keep
features_to_keep = [
    'Timestamp', 'Src IP', 'Src Port', 'Dst IP', 'Protocol', 'TotLen Fwd Pkts', 'TotLen Bwd Pkts',
    'Fwd Pkt Len Max', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Mean',
    'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow IAT Std', 'Flow IAT Min',
    'Fwd IAT Std', 'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max',
    'Bwd IAT Min', 'Fwd Header Len', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std',
    'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt',
    'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg', 'Subflow Fwd Byts',
    'Subflow Bwd Byts', 'Init Fwd Win Byts', 'Fwd Act Data Pkts', 'Fwd Seg Size Min',
    'Idle Mean', 'Idle Max', 'Idle Min', 'Label'
]

# Load your dataset
data = pd.read_csv('train_data.csv')  # Replace 'your_data.csv' with your actual file name

# Keep only the specified features
filtered_data = data[features_to_keep]

# Convert 'Timestamp' to datetime
filtered_data['Timestamp'] = pd.to_datetime(filtered_data['Timestamp'])

# Order the data by 'Timestamp'
filtered_data = filtered_data.sort_values(by='Timestamp')

# Save the temporally ordered data to a new file
filtered_data.to_csv('filtered_train_3edge.csv', index=False)

print("Filtered and temporally ordered data saved to 'filtered_train_3edge.csv'.")
# Out:
# /tmp/ipykernel_3887039/3618146485.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Timestamp'] = pd.to_datetime(filtered_data['Timestamp'])
# Filtered and temporally ordered data saved to 'filtered_train_3edge.csv'.

# %%
#check for inside of csv (just for test, no need for run)
import pandas as pd

# Load the CSV file
file_path = "filtered_train_3edge.csv"  # Replace with your actual file path
df = pd.read_csv(file_path)

# Check if the label column contains '1'
label_column = 'Label'  # Replace with the actual label column name if different
if label_column in df.columns:
    label_distribution = df[label_column].value_counts()
    print("Label Distribution:")
    print(label_distribution)

    if 1 in label_distribution.index:
        print("The CSV contains label '1'.")
    else:
        print("The CSV does NOT contain label '1'.")
else:
    print(f"'{label_column}' column not found in the CSV.")
# Out:
# Label Distribution:
# Label
# 1    1978039
# 0    1208711
# Name: count, dtype: int64
# The CSV contains label '1'.

# %% [markdown]
# # created hourly graph with 3 edges from train dataset

# %%
import pandas as pd
import networkx as nx
import os

def create_test_graphs_edge_labels(df, output_dir):
    """
    Split the DataFrame into hourly slices and create graphs for each slice.
    Each edge gets a valid label (e.g., 0 or 1) read from the DataFrame.
    
    Parameters:
        df (pd.DataFrame): The input DataFrame with temporal data.
        output_dir (str): Directory to save the graphs.
    """
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    # Group the DataFrame into hourly slices using the datetime index.
    # (Assumes the DataFrame index is already a DateTimeIndex)
    time_slices = [g for _, g in df.groupby(pd.Grouper(freq='H'))]
    
    for slice_index, slice_df in enumerate(time_slices):
        if slice_df.empty:
            continue

        # Print value counts of the 'Label' column in this time-slice.
        print(f"Hour {slice_index}:")
        print(slice_df['Label'].value_counts())
        
        # Create a MultiDiGraph for this time-slice.
        G = nx.MultiDiGraph()

        for _, row in slice_df.iterrows():
            src_ip = row['Src IP']
            dst_ip = row['Dst IP']
            
            # Convert the label to an int (if missing or invalid, you can decide a fallback; here we assume it is valid)
            try:
                label = int(row['Label'])
            except Exception as e:
                print(f"Skipping row due to invalid label: {row['Label']}; error: {e}")
                continue

            if pd.isna(src_ip) or pd.isna(dst_ip):
                continue

            # Add nodes if not already present.
            if not G.has_node(src_ip):
                G.add_node(src_ip)
            if not G.has_node(dst_ip):
                G.add_node(dst_ip)

            # Add edges for different interactions.
            # 1. Network Edge
            G.add_edge(src_ip, dst_ip, key='network',
                       label=label,
                       src_port=row.get('Src Port', 0),
                       protocol=row.get('Protocol', 0),
                       fwd_header_len=row.get('Fwd Header Len', 0),
                       syn_flag_cnt=row.get('SYN Flag Cnt', 0),
                       psh_flag_cnt=row.get('PSH Flag Cnt', 0),
                       ack_flag_cnt=row.get('ACK Flag Cnt', 0),
                       fin_flag_cnt=row.get('FIN Flag Cnt', 0),
                       subflow_fwd_byts=row.get('Subflow Fwd Byts', 0),
                       subflow_bwd_byts=row.get('Subflow Bwd Byts', 0),
                       init_fwd_win_byts=row.get('Init Fwd Win Byts', 0),
                       interaction='network_communication')

            # 2. Context Edge
            G.add_edge(src_ip, dst_ip, key='context',
                       label=label,
                       flow_iat_std=row.get('Flow IAT Std', 0),
                       flow_iat_min=row.get('Flow IAT Min', 0),
                       fwd_iat_std=row.get('Fwd IAT Std', 0),
                       bwd_iat_tot=row.get('Bwd IAT Tot', 0),
                       bwd_iat_mean=row.get('Bwd IAT Mean', 0),
                       bwd_iat_std=row.get('Bwd IAT Std', 0),
                       bwd_iat_max=row.get('Bwd IAT Max', 0),
                       bwd_iat_min=row.get('Bwd IAT Min', 0),
                       idle_mean=row.get('Idle Mean', 0),
                       idle_max=row.get('Idle Max', 0),
                       idle_min=row.get('Idle Min', 0),
                       interaction='context')

            # 3. Knowledge Edge
            G.add_edge(src_ip, dst_ip, key='knowledge',
                       label=label,
                       totlen_fwd_pkts=row.get('TotLen Fwd Pkts', 0),
                       totlen_bwd_pkts=row.get('TotLen Bwd Pkts', 0),
                       fwd_pkt_len_max=row.get('Fwd Pkt Len Max', 0),
                       fwd_pkt_len_mean=row.get('Fwd Pkt Len Mean', 0),
                       fwd_pkt_len_std=row.get('Fwd Pkt Len Std', 0),
                       bwd_pkt_len_mean=row.get('Bwd Pkt Len Mean', 0),
                       bwd_pkt_len_std=row.get('Bwd Pkt Len Std', 0),
                       flow_byts_per_sec=row.get('Flow Byts/s', 0),
                       pkt_len_max=row.get('Pkt Len Max', 0),
                       pkt_len_mean=row.get('Pkt Len Mean', 0),
                       pkt_len_std=row.get('Pkt Len Std', 0),
                       pkt_len_var=row.get('Pkt Len Var', 0),
                       pkt_size_avg=row.get('Pkt Size Avg', 0),
                       fwd_seg_size_avg=row.get('Fwd Seg Size Avg', 0),
                       bwd_seg_size_avg=row.get('Bwd Seg Size Avg', 0),
                       fwd_act_data_pkts=row.get('Fwd Act Data Pkts', 0),
                       fwd_seg_size_min=row.get('Fwd Seg Size Min', 0),
                       interaction='knowledge')

        # Save the graph as a .gpickle file.
        graph_path = os.path.join(output_dir, f"test_graph_hour_{slice_index}.gpickle")
        nx.write_gpickle(G, graph_path)
        print(f"Test graph for hour {slice_index} saved to {graph_path}")

# Usage Example for graph creation
if __name__ == "__main__":
    # Read CSV and prepare DataFrame.
    df_test = pd.read_csv('filtered_train_3edge.csv')
    df_test['Timestamp'] = pd.to_datetime(df_test['Timestamp'])
    # Set Timestamp as index and sort (required for grouping by hour)
    df_test = df_test.set_index('Timestamp').sort_index()

    output_test_dir = "3ed_trai_h_graphs"
    create_test_graphs_edge_labels(df_test, output_test_dir)
# Out:
# Hour 0:
# Label
# 0    558
# Name: count, dtype: int64
# Test graph for hour 0 saved to 3ed_trai_h_graphs/test_graph_hour_0.gpickle
# Hour 1:
# Label
# 0    475
# Name: count, dtype: int64
# Test graph for hour 1 saved to 3ed_trai_h_graphs/test_graph_hour_1.gpickle
# Hour 2:
# Label
# 0    551
# Name: count, dtype: int64
# Test graph for hour 2 saved to 3ed_trai_h_graphs/test_graph_hour_2.gpickle
# Hour 3:
# Label
# 0    1251
# Name: count, dtype: int64
# Test graph for hour 3 saved to 3ed_trai_h_graphs/test_graph_hour_3.gpickle
# Hour 4:
# Label
# 0    1513
# Name: count, dtype: int64
# Test graph for hour 4 saved to 3ed_trai_h_graphs/test_graph_hour_4.gpickle
# Hour 5:
# Label
# 0    1397
# Name: count, dtype: int64
# Test graph for hour 5 saved to 3ed_trai_h_graphs/test_graph_hour_5.gpickle
# Hour 6:
# Label
# 0    1468
# Name: count, dtype: int64
# Test graph for hour 6 saved to 3ed_trai_h_graphs/test_graph_hour_6.gpickle
# Hour 7:
# Label
# 0    1382
# Name: count, dtype: int64
# Test graph for hour 7 saved to 3ed_trai_h_graphs/test_graph_hour_7.gpickle
# Hour 8:
# Label
# 0    1503
# Name: count, dtype: int64
# Test graph for hour 8 saved to 3ed_trai_h_graphs/test_graph_hour_8.gpickle
# Hour 9:
# Label
# 0    1566
# Name: count, dtype: int64
# Test graph for hour 9 saved to 3ed_trai_h_graphs/test_graph_hour_9.gpickle
# Hour 10:
# Label
# 0    1702
# Name: count, dtype: int64
# Test graph for hour 10 saved to 3ed_trai_h_graphs/test_graph_hour_10.gpickle
# Hour 11:
# Label
# 0    1652
# Name: count, dtype: int64
# Test graph for hour 11 saved to 3ed_trai_h_graphs/test_graph_hour_11.gpickle
# Hour 12:
# Label
# 0    1847
# Name: count, dtype: int64
# Test graph for hour 12 saved to 3ed_trai_h_graphs/test_graph_hour_12.gpickle
# Hour 13:
# Label
# 0    1390
# Name: count, dtype: int64
# Test graph for hour 13 saved to 3ed_trai_h_graphs/test_graph_hour_13.gpickle
# Hour 14:
# Label
# 1    26290
# 0     4073
# Name: count, dtype: int64
# Test graph for hour 14 saved to 3ed_trai_h_graphs/test_graph_hour_14.gpickle
# Hour 15:
# Label
# 1    366353
# 0    159638
# Name: count, dtype: int64
# Test graph for hour 15 saved to 3ed_trai_h_graphs/test_graph_hour_15.gpickle
# Hour 16:
# Label
# 1    353926
# 0    285549
# Name: count, dtype: int64
# Test graph for hour 16 saved to 3ed_trai_h_graphs/test_graph_hour_16.gpickle
# Hour 17:
# Label
# 1    354314
# 0    213991
# Name: count, dtype: int64
# Test graph for hour 17 saved to 3ed_trai_h_graphs/test_graph_hour_17.gpickle
# Hour 18:
# Label
# 1    359961
# 0    227323
# Name: count, dtype: int64
# Test graph for hour 18 saved to 3ed_trai_h_graphs/test_graph_hour_18.gpickle
# Hour 19:
# Label
# 1    388078
# 0    215716
# Name: count, dtype: int64
# Test graph for hour 19 saved to 3ed_trai_h_graphs/test_graph_hour_19.gpickle
# Hour 20:
# Label
# 1    129117
# 0     84166
# Name: count, dtype: int64
# Test graph for hour 20 saved to 3ed_trai_h_graphs/test_graph_hour_20.gpickle

# %% [markdown]
# # Community detection for graphs and then update the graph with the label of community for each node

# %%
import networkx as nx
import os

def detect_and_label_communities_lpa(graph):
    """
    Perform community detection using the Label Propagation Algorithm (LPA) and label nodes with community IDs.
    Adds 'x' attribute based on the 'community' label.

    Parameters:
        graph (nx.MultiDiGraph): Input graph.

    Returns:
        graph (nx.MultiDiGraph): Updated graph with community labels and 'x' attributes.
    """
    # Convert MultiDiGraph to Graph (undirected graph for LPA)
    undirected_graph = nx.Graph(graph)

    # Perform community detection using LPA
    communities = nx.community.label_propagation_communities(undirected_graph)

    # Assign community labels to nodes and add 'x' attribute
    for community_id, community in enumerate(communities):
        for node in community:
            graph.nodes[node]['community'] = community_id
            graph.nodes[node]['x'] = [community_id]  # 'x' is a feature; wrap in a list for PyTorch Geometric compatibility

    return graph


def process_graphs_with_lpa(input_dir, output_dir):
    """
    Detect communities using LPA, update graphs with community labels, and add 'x' attribute.
    
    Parameters:
        input_dir (str): Directory containing input graphs.
        output_dir (str): Directory to save updated graphs.
    """
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Process each graph file in the input directory
    for graph_file in os.listdir(input_dir):
        if not graph_file.endswith('.gpickle'):
            continue
        
        # Load the graph
        graph_path = os.path.join(input_dir, graph_file)
        G = nx.read_gpickle(graph_path)

        # Detect communities using LPA and label nodes
        G = detect_and_label_communities_lpa(G)

        # Save the updated graph
        updated_graph_path = os.path.join(output_dir, graph_file)
        nx.write_gpickle(G, updated_graph_path)
        print(f"Updated graph with LPA communities and 'x' attribute saved to {updated_graph_path}")


# Example usage
if __name__ == "__main__":
    # Input directory containing graphs
    input_graph_dir = "3ed_trai_h_graphs"

    # Output directory for updated graphs
    output_graph_dir = "3ed_trai_h_graphs_commun"

    # Process graphs and add community labels using LPA
    process_graphs_with_lpa(input_graph_dir, output_graph_dir)
# Out:
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_14.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_17.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_13.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_18.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_1.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_12.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_11.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_6.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_5.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_4.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_2.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_10.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_16.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_15.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_8.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_20.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_7.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_3.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_0.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_9.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_trai_h_graphs_commun/test_graph_hour_19.gpickle

# %% [markdown]
# # convert Multigraph to hetrodata

# %%
import torch
from torch_geometric.data import HeteroData
import networkx as nx
import os

def multiDiGraph_to_hetero_with_label(G: nx.MultiDiGraph) -> HeteroData:
    """
    Converts a MultiDiGraph with multiple edge types to a HeteroData object.
    Preserves the 'label' field in data[rel_type].edge_label.
    """
    data = HeteroData()
    node_mapping = {node: i for i, node in enumerate(G.nodes())}
    data['ip'].num_nodes = G.number_of_nodes()

    # Add node-level features
    x = []
    community_labels = []
    for node in G.nodes():
        community = G.nodes[node].get('community', -1)
        community_labels.append(community)
        x.append([community])
    data['ip'].community = torch.tensor(community_labels, dtype=torch.long)
    data['ip'].x = torch.tensor(x, dtype=torch.float)

    # Process each edge from G.
    for u, v, key, edge_attrs in G.edges(data=True, keys=True):
        src = node_mapping[u]
        dst = node_mapping[v]
        rel_type = ('ip', key, 'ip')
        if rel_type not in data.edge_types:
            data[rel_type].edge_index = []
            data[rel_type].edge_attr = []
            data[rel_type].edge_label = []  # Container for the label

        data[rel_type].edge_index.append([src, dst])
        feature_vec = []
        if key == 'network':
            for attr_name in ['Src Port', 'Protocol', 'Fwd Header Len', 'SYN Flag Cnt',
                              'PSH Flag Cnt', 'ACK Flag Cnt', 'FIN Flag Cnt',
                              'Subflow Fwd Byts', 'Subflow Bwd Byts', 'Init Fwd Win Byts']:
                feature_vec.append(edge_attrs.get(attr_name, 0))
        elif key == 'context':
            for attr_name in ['Flow IAT Std', 'Flow IAT Min', 'Fwd IAT Std', 'Bwd IAT Tot',
                              'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min',
                              'Idle Mean', 'Idle Max', 'Idle Min']:
                feature_vec.append(edge_attrs.get(attr_name, 0))
        elif key == 'knowledge':
            for attr_name in ['TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max',
                              'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Mean',
                              'Bwd Pkt Len Std', 'Flow Byts/s', 'Pkt Len Max', 'Pkt Len Mean',
                              'Pkt Len Std', 'Pkt Len Var', 'Pkt Size Avg', 'Fwd Seg Size Avg',
                              'Bwd Seg Size Avg', 'Fwd Act Data Pkts', 'Fwd Seg Size Min']:
                feature_vec.append(edge_attrs.get(attr_name, 0))
        data[rel_type].edge_attr.append(feature_vec)
        # Save the label—this should now be valid (0 or 1)
        data[rel_type].edge_label.append(edge_attrs.get('label', -1))

    # Convert lists to tensors.
    for rel_type in data.edge_types:
        data[rel_type].edge_index = torch.tensor(data[rel_type].edge_index, dtype=torch.long).t().contiguous()
        if data[rel_type].edge_attr:
            data[rel_type].edge_attr = torch.tensor(data[rel_type].edge_attr, dtype=torch.float)
        if data[rel_type].edge_label:
            data[rel_type].edge_label = torch.tensor(data[rel_type].edge_label, dtype=torch.long)
    return data

def process_and_save_hetero_graphs_with_label(input_dir, output_dir):
    """
    Converts all .gpickle graphs in a directory to HeteroData objects and saves them as .pt,
    preserving the 'label' field in data[rel_type].edge_label.
    """
    os.makedirs(output_dir, exist_ok=True)
    for graph_file in os.listdir(input_dir):
        if not graph_file.endswith('.gpickle'):
            continue
        graph_path = os.path.join(input_dir, graph_file)
        G = nx.read_gpickle(graph_path)
        hetero_data = multiDiGraph_to_hetero_with_label(G)
        hetero_path = os.path.join(output_dir, graph_file.replace('.gpickle', '.pt'))
        torch.save(hetero_data, hetero_path)
        print(f"Saved HeteroData with labels to {hetero_path}")

if __name__ == "__main__":
    input_test_dir = "3ed_trai_h_graphs_commun"         # Input .gpickle files (with communities added)
    output_test_pt_dir = "3ed_trai_h_graphs_hetero_graphs" # Output .pt files
    process_and_save_hetero_graphs_with_label(input_test_dir, output_test_pt_dir)
# Out:
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_14.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_17.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_13.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_18.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_1.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_12.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_11.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_6.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_5.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_4.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_2.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_10.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_16.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_15.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_8.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_20.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_7.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_3.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_0.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_9.pt
# Saved HeteroData with labels to 3ed_trai_h_graphs_hetero_graphs/test_graph_hour_19.pt

# %% [markdown]
# # Test for inside of graph, no need to run it

# %%
#was test for inside of .pt ( no need to run)
import torch
import os

def inspect_pt_file(file_path):
    """
    Inspects the contents of a .pt file and prints its structure.

    Parameters:
        file_path (str): Path to the .pt file.
    """
    data = torch.load(file_path)
    print(f"Inspecting file: {file_path}")
    print("-" * 40)

    # Check if it's a PyTorch Geometric HeteroData object
    if isinstance(data, dict):
        print("File contains a dictionary. Keys:")
        for key, value in data.items():
            print(f"  {key}: {type(value)}")
            if isinstance(value, torch.Tensor):
                print(f"    Tensor shape: {value.shape}")
    elif hasattr(data, 'keys') and hasattr(data, 'edge_index_dict'):
        print("File contains a HeteroData object.")
        print(f"Node types: {data.node_types}")
        for node_type in data.node_types:
            print(f"  Node type '{node_type}':")
            if 'x' in data[node_type]:
                print(f"    Node features 'x': shape {data[node_type].x.shape}")
            else:
                print("    No node features ('x') found.")
            if 'num_nodes' in data[node_type]:
                print(f"    Number of nodes: {data[node_type].num_nodes}")
        
        print(f"Edge types: {data.edge_types}")
        for edge_type in data.edge_types:
            print(f"  Edge type {edge_type}:")
            if 'edge_index' in data[edge_type]:
                print(f"    Edge index: shape {data[edge_type].edge_index.shape}")
            if 'edge_attr' in data[edge_type]:
                print(f"    Edge attributes: shape {data[edge_type].edge_attr.shape}")
    else:
        print("Unknown data format.")
    print("-" * 40)

def inspect_all_pt_files(directory):
    """
    Inspects all .pt files in a given directory.

    Parameters:
        directory (str): Path to the directory containing .pt files.
    """
    print(f"Inspecting .pt files in directory: {directory}")
    for file in os.listdir(directory):
        if file.endswith(".pt"):
            inspect_pt_file(os.path.join(directory, file))

# Directory containing your .pt files
input_graph_dir = "3ed_trai_h_graphs_hetero_graphs"

# Inspect all files in the directory
inspect_all_pt_files(input_graph_dir)
# Out:
# Inspecting .pt files in directory: 3ed_trai_h_graphs_hetero_graphs
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1876.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([17604, 1])
#     Number of nodes: 17604
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 19038])
#     Edge attributes: shape torch.Size([19038, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 19038])
#     Edge attributes: shape torch.Size([19038, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 19038])
#     Edge attributes: shape torch.Size([19038, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1967.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([125, 1])
#     Number of nodes: 125
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 175])
#     Edge attributes: shape torch.Size([175, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 175])
#     Edge attributes: shape torch.Size([175, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 175])
#     Edge attributes: shape torch.Size([175, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1414.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([30, 1])
#     Number of nodes: 30
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 25])
#     Edge attributes: shape torch.Size([25, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 25])
#     Edge attributes: shape torch.Size([25, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 25])
#     Edge attributes: shape torch.Size([25, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_2019.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([510, 1])
#     Number of nodes: 510
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 587])
#     Edge attributes: shape torch.Size([587, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 587])
#     Edge attributes: shape torch.Size([587, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 587])
#     Edge attributes: shape torch.Size([587, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_654.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([93, 1])
#     Number of nodes: 93
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 86])
#     Edge attributes: shape torch.Size([86, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 86])
#     Edge attributes: shape torch.Size([86, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 86])
#     Edge attributes: shape torch.Size([86, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_659.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([31, 1])
#     Number of nodes: 31
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 25])
#     Edge attributes: shape torch.Size([25, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 25])
#     Edge attributes: shape torch.Size([25, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 25])
#     Edge attributes: shape torch.Size([25, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1399.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([43, 1])
#     Number of nodes: 43
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 40])
#     Edge attributes: shape torch.Size([40, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 40])
#     Edge attributes: shape torch.Size([40, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 40])
#     Edge attributes: shape torch.Size([40, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1882.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([216, 1])
#     Number of nodes: 216
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 195])
#     Edge attributes: shape torch.Size([195, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 195])
#     Edge attributes: shape torch.Size([195, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 195])
#     Edge attributes: shape torch.Size([195, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_2012.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([63, 1])
#     Number of nodes: 63
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 74])
#     Edge attributes: shape torch.Size([74, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 74])
#     Edge attributes: shape torch.Size([74, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 74])
#     Edge attributes: shape torch.Size([74, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1930.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([4918, 1])
#     Number of nodes: 4918
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 5066])
#     Edge attributes: shape torch.Size([5066, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 5066])
#     Edge attributes: shape torch.Size([5066, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 5066])
#     Edge attributes: shape torch.Size([5066, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1929.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([2189, 1])
#     Number of nodes: 2189
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 2189])
#     Edge attributes: shape torch.Size([2189, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 2189])
#     Edge attributes: shape torch.Size([2189, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 2189])
#     Edge attributes: shape torch.Size([2189, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_2002.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([163, 1])
#     Number of nodes: 163
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 187])
#     Edge attributes: shape torch.Size([187, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 187])
#     Edge attributes: shape torch.Size([187, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 187])
#     Edge attributes: shape torch.Size([187, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1400.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([28, 1])
#     Number of nodes: 28
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 24])
#     Edge attributes: shape torch.Size([24, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 24])
#     Edge attributes: shape torch.Size([24, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 24])
#     Edge attributes: shape torch.Size([24, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1887.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([159, 1])
#     Number of nodes: 159
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 141])
#     Edge attributes: shape torch.Size([141, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 141])
#     Edge attributes: shape torch.Size([141, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 141])
#     Edge attributes: shape torch.Size([141, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_2010.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([126, 1])
#     Number of nodes: 126
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 142])
#     Edge attributes: shape torch.Size([142, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 142])
#     Edge attributes: shape torch.Size([142, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 142])
#     Edge attributes: shape torch.Size([142, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1992.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([199, 1])
#     Number of nodes: 199
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 236])
#     Edge attributes: shape torch.Size([236, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 236])
#     Edge attributes: shape torch.Size([236, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 236])
#     Edge attributes: shape torch.Size([236, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_657.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([32, 1])
#     Number of nodes: 32
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 26])
#     Edge attributes: shape torch.Size([26, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 26])
#     Edge attributes: shape torch.Size([26, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 26])
#     Edge attributes: shape torch.Size([26, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_2015.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([107, 1])
#     Number of nodes: 107
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 129])
#     Edge attributes: shape torch.Size([129, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 129])
#     Edge attributes: shape torch.Size([129, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 129])
#     Edge attributes: shape torch.Size([129, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_675.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([33, 1])
#     Number of nodes: 33
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 28])
#     Edge attributes: shape torch.Size([28, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 28])
#     Edge attributes: shape torch.Size([28, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 28])
#     Edge attributes: shape torch.Size([28, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_2009.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([65, 1])
#     Number of nodes: 65
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 75])
#     Edge attributes: shape torch.Size([75, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 75])
#     Edge attributes: shape torch.Size([75, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 75])
#     Edge attributes: shape torch.Size([75, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_656.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([54, 1])
#     Number of nodes: 54
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 47])
#     Edge attributes: shape torch.Size([47, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 47])
#     Edge attributes: shape torch.Size([47, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 47])
#     Edge attributes: shape torch.Size([47, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_2016.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([131, 1])
#     Number of nodes: 131
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 147])
#     Edge attributes: shape torch.Size([147, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 147])
#     Edge attributes: shape torch.Size([147, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 147])
#     Edge attributes: shape torch.Size([147, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_2005.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([76, 1])
#     Number of nodes: 76
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 89])
#     Edge attributes: shape torch.Size([89, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 89])
#     Edge attributes: shape torch.Size([89, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 89])
#     Edge attributes: shape torch.Size([89, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_658.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([32, 1])
#     Number of nodes: 32
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 26])
#     Edge attributes: shape torch.Size([26, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 26])
#     Edge attributes: shape torch.Size([26, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 26])
#     Edge attributes: shape torch.Size([26, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_3.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([75, 1])
#     Number of nodes: 75
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 68])
#     Edge attributes: shape torch.Size([68, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 68])
#     Edge attributes: shape torch.Size([68, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 68])
#     Edge attributes: shape torch.Size([68, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1879.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([16743, 1])
#     Number of nodes: 16743
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 17240])
#     Edge attributes: shape torch.Size([17240, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 17240])
#     Edge attributes: shape torch.Size([17240, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 17240])
#     Edge attributes: shape torch.Size([17240, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1999.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([114, 1])
#     Number of nodes: 114
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 134])
#     Edge attributes: shape torch.Size([134, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 134])
#     Edge attributes: shape torch.Size([134, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 134])
#     Edge attributes: shape torch.Size([134, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1937.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([4006, 1])
#     Number of nodes: 4006
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 4076])
#     Edge attributes: shape torch.Size([4076, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 4076])
#     Edge attributes: shape torch.Size([4076, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 4076])
#     Edge attributes: shape torch.Size([4076, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_2004.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([94, 1])
#     Number of nodes: 94
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 110])
#     Edge attributes: shape torch.Size([110, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 110])
#     Edge attributes: shape torch.Size([110, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 110])
#     Edge attributes: shape torch.Size([110, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1413.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([27, 1])
#     Number of nodes: 27
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 22])
#     Edge attributes: shape torch.Size([22, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 22])
#     Edge attributes: shape torch.Size([22, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 22])
#     Edge attributes: shape torch.Size([22, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1884.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([192, 1])
#     Number of nodes: 192
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 175])
#     Edge attributes: shape torch.Size([175, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 175])
#     Edge attributes: shape torch.Size([175, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 175])
#     Edge attributes: shape torch.Size([175, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_2.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([60, 1])
#     Number of nodes: 60
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 52])
#     Edge attributes: shape torch.Size([52, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 52])
#     Edge attributes: shape torch.Size([52, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 52])
#     Edge attributes: shape torch.Size([52, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1403.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([33, 1])
#     Number of nodes: 33
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 28])
#     Edge attributes: shape torch.Size([28, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 28])
#     Edge attributes: shape torch.Size([28, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 28])
#     Edge attributes: shape torch.Size([28, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1987.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([567, 1])
#     Number of nodes: 567
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 655])
#     Edge attributes: shape torch.Size([655, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 655])
#     Edge attributes: shape torch.Size([655, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 655])
#     Edge attributes: shape torch.Size([655, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1910.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([206, 1])
#     Number of nodes: 206
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 171])
#     Edge attributes: shape torch.Size([171, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 171])
#     Edge attributes: shape torch.Size([171, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 171])
#     Edge attributes: shape torch.Size([171, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1907.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([147, 1])
#     Number of nodes: 147
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 116])
#     Edge attributes: shape torch.Size([116, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 116])
#     Edge attributes: shape torch.Size([116, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 116])
#     Edge attributes: shape torch.Size([116, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1919.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([298, 1])
#     Number of nodes: 298
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 273])
#     Edge attributes: shape torch.Size([273, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 273])
#     Edge attributes: shape torch.Size([273, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 273])
#     Edge attributes: shape torch.Size([273, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1966.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([163, 1])
#     Number of nodes: 163
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 213])
#     Edge attributes: shape torch.Size([213, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 213])
#     Edge attributes: shape torch.Size([213, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 213])
#     Edge attributes: shape torch.Size([213, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1895.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([286, 1])
#     Number of nodes: 286
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 264])
#     Edge attributes: shape torch.Size([264, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 264])
#     Edge attributes: shape torch.Size([264, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 264])
#     Edge attributes: shape torch.Size([264, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_4.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([48, 1])
#     Number of nodes: 48
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 41])
#     Edge attributes: shape torch.Size([41, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 41])
#     Edge attributes: shape torch.Size([41, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 41])
#     Edge attributes: shape torch.Size([41, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1994.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([105, 1])
#     Number of nodes: 105
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 133])
#     Edge attributes: shape torch.Size([133, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 133])
#     Edge attributes: shape torch.Size([133, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 133])
#     Edge attributes: shape torch.Size([133, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1964.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([209, 1])
#     Number of nodes: 209
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 266])
#     Edge attributes: shape torch.Size([266, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 266])
#     Edge attributes: shape torch.Size([266, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 266])
#     Edge attributes: shape torch.Size([266, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1963.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([208, 1])
#     Number of nodes: 208
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 243])
#     Edge attributes: shape torch.Size([243, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 243])
#     Edge attributes: shape torch.Size([243, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 243])
#     Edge attributes: shape torch.Size([243, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1942.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([351, 1])
#     Number of nodes: 351
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 329])
#     Edge attributes: shape torch.Size([329, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 329])
#     Edge attributes: shape torch.Size([329, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 329])
#     Edge attributes: shape torch.Size([329, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1401.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([35, 1])
#     Number of nodes: 35
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 30])
#     Edge attributes: shape torch.Size([30, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 30])
#     Edge attributes: shape torch.Size([30, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 30])
#     Edge attributes: shape torch.Size([30, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_655.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([142, 1])
#     Number of nodes: 142
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 136])
#     Edge attributes: shape torch.Size([136, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 136])
#     Edge attributes: shape torch.Size([136, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 136])
#     Edge attributes: shape torch.Size([136, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1411.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([35, 1])
#     Number of nodes: 35
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 31])
#     Edge attributes: shape torch.Size([31, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 31])
#     Edge attributes: shape torch.Size([31, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 31])
#     Edge attributes: shape torch.Size([31, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1935.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([5465, 1])
#     Number of nodes: 5465
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 5607])
#     Edge attributes: shape torch.Size([5607, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 5607])
#     Edge attributes: shape torch.Size([5607, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 5607])
#     Edge attributes: shape torch.Size([5607, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1407.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([27, 1])
#     Number of nodes: 27
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 22])
#     Edge attributes: shape torch.Size([22, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 22])
#     Edge attributes: shape torch.Size([22, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 22])
#     Edge attributes: shape torch.Size([22, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_653.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([46, 1])
#     Number of nodes: 46
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 41])
#     Edge attributes: shape torch.Size([41, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 41])
#     Edge attributes: shape torch.Size([41, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 41])
#     Edge attributes: shape torch.Size([41, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1991.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([187, 1])
#     Number of nodes: 187
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 223])
#     Edge attributes: shape torch.Size([223, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 223])
#     Edge attributes: shape torch.Size([223, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 223])
#     Edge attributes: shape torch.Size([223, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1918.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([130, 1])
#     Number of nodes: 130
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 107])
#     Edge attributes: shape torch.Size([107, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 107])
#     Edge attributes: shape torch.Size([107, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 107])
#     Edge attributes: shape torch.Size([107, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1408.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([29, 1])
#     Number of nodes: 29
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 25])
#     Edge attributes: shape torch.Size([25, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 25])
#     Edge attributes: shape torch.Size([25, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 25])
#     Edge attributes: shape torch.Size([25, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1911.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([204, 1])
#     Number of nodes: 204
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 171])
#     Edge attributes: shape torch.Size([171, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 171])
#     Edge attributes: shape torch.Size([171, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 171])
#     Edge attributes: shape torch.Size([171, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1931.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([6058, 1])
#     Number of nodes: 6058
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 6248])
#     Edge attributes: shape torch.Size([6248, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 6248])
#     Edge attributes: shape torch.Size([6248, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 6248])
#     Edge attributes: shape torch.Size([6248, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1968.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([99, 1])
#     Number of nodes: 99
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 131])
#     Edge attributes: shape torch.Size([131, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 131])
#     Edge attributes: shape torch.Size([131, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 131])
#     Edge attributes: shape torch.Size([131, 17])
# ----------------------------------------
# /tmp/ipykernel_1340014/2292571266.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(file_path)
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1885.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([163, 1])
#     Number of nodes: 163
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 147])
#     Edge attributes: shape torch.Size([147, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 147])
#     Edge attributes: shape torch.Size([147, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 147])
#     Edge attributes: shape torch.Size([147, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1906.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([181, 1])
#     Number of nodes: 181
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 150])
#     Edge attributes: shape torch.Size([150, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 150])
#     Edge attributes: shape torch.Size([150, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 150])
#     Edge attributes: shape torch.Size([150, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1912.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([199, 1])
#     Number of nodes: 199
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 169])
#     Edge attributes: shape torch.Size([169, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 169])
#     Edge attributes: shape torch.Size([169, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 169])
#     Edge attributes: shape torch.Size([169, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1397.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([25, 1])
#     Number of nodes: 25
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 20])
#     Edge attributes: shape torch.Size([20, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 20])
#     Edge attributes: shape torch.Size([20, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 20])
#     Edge attributes: shape torch.Size([20, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_676.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([33, 1])
#     Number of nodes: 33
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 28])
#     Edge attributes: shape torch.Size([28, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 28])
# ...
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 176])
#     Edge attributes: shape torch.Size([176, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 176])
#     Edge attributes: shape torch.Size([176, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 176])
#     Edge attributes: shape torch.Size([176, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1934.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([5820, 1])
#     Number of nodes: 5820
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 5972])
#     Edge attributes: shape torch.Size([5972, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 5972])
#     Edge attributes: shape torch.Size([5972, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 5972])
#     Edge attributes: shape torch.Size([5972, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_0.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([6, 1])
#     Number of nodes: 6
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 3])
#     Edge attributes: shape torch.Size([3, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 3])
#     Edge attributes: shape torch.Size([3, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 3])
#     Edge attributes: shape torch.Size([3, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1410.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([24, 1])
#     Number of nodes: 24
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 20])
#     Edge attributes: shape torch.Size([20, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 20])
#     Edge attributes: shape torch.Size([20, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 20])
#     Edge attributes: shape torch.Size([20, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1996.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([175, 1])
#     Number of nodes: 175
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 204])
#     Edge attributes: shape torch.Size([204, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 204])
#     Edge attributes: shape torch.Size([204, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 204])
#     Edge attributes: shape torch.Size([204, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1925.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([232, 1])
#     Number of nodes: 232
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 196])
#     Edge attributes: shape torch.Size([196, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 196])
#     Edge attributes: shape torch.Size([196, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 196])
#     Edge attributes: shape torch.Size([196, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1995.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([117, 1])
#     Number of nodes: 117
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 138])
#     Edge attributes: shape torch.Size([138, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 138])
#     Edge attributes: shape torch.Size([138, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 138])
#     Edge attributes: shape torch.Size([138, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_2021.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([137853, 1])
#     Number of nodes: 137853
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 184666])
#     Edge attributes: shape torch.Size([184666, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 184666])
#     Edge attributes: shape torch.Size([184666, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 184666])
#     Edge attributes: shape torch.Size([184666, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1888.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([165, 1])
#     Number of nodes: 165
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 150])
#     Edge attributes: shape torch.Size([150, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 150])
#     Edge attributes: shape torch.Size([150, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 150])
#     Edge attributes: shape torch.Size([150, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1896.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([15635, 1])
#     Number of nodes: 15635
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 16497])
#     Edge attributes: shape torch.Size([16497, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 16497])
#     Edge attributes: shape torch.Size([16497, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 16497])
#     Edge attributes: shape torch.Size([16497, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1932.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([5648, 1])
#     Number of nodes: 5648
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 5829])
#     Edge attributes: shape torch.Size([5829, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 5829])
#     Edge attributes: shape torch.Size([5829, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 5829])
#     Edge attributes: shape torch.Size([5829, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_671.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([18, 1])
#     Number of nodes: 18
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 11])
#     Edge attributes: shape torch.Size([11, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 11])
#     Edge attributes: shape torch.Size([11, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 11])
#     Edge attributes: shape torch.Size([11, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_2006.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([98, 1])
#     Number of nodes: 98
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 113])
#     Edge attributes: shape torch.Size([113, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 113])
#     Edge attributes: shape torch.Size([113, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 113])
#     Edge attributes: shape torch.Size([113, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1893.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([1438, 1])
#     Number of nodes: 1438
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 1438])
#     Edge attributes: shape torch.Size([1438, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 1438])
#     Edge attributes: shape torch.Size([1438, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 1438])
#     Edge attributes: shape torch.Size([1438, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1892.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([3010, 1])
#     Number of nodes: 3010
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 3038])
#     Edge attributes: shape torch.Size([3038, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 3038])
#     Edge attributes: shape torch.Size([3038, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 3038])
#     Edge attributes: shape torch.Size([3038, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1941.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([2730, 1])
#     Number of nodes: 2730
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 2630])
#     Edge attributes: shape torch.Size([2630, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 2630])
#     Edge attributes: shape torch.Size([2630, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 2630])
#     Edge attributes: shape torch.Size([2630, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([36, 1])
#     Number of nodes: 36
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 30])
#     Edge attributes: shape torch.Size([30, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 30])
#     Edge attributes: shape torch.Size([30, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 30])
#     Edge attributes: shape torch.Size([30, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1412.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([22, 1])
#     Number of nodes: 22
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 17])
#     Edge attributes: shape torch.Size([17, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 17])
#     Edge attributes: shape torch.Size([17, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 17])
#     Edge attributes: shape torch.Size([17, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1886.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([198, 1])
#     Number of nodes: 198
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 177])
#     Edge attributes: shape torch.Size([177, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 177])
#     Edge attributes: shape torch.Size([177, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 177])
#     Edge attributes: shape torch.Size([177, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1409.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([36, 1])
#     Number of nodes: 36
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 31])
#     Edge attributes: shape torch.Size([31, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 31])
#     Edge attributes: shape torch.Size([31, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 31])
#     Edge attributes: shape torch.Size([31, 17])
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_hetero_graphs/graph_hour_1398.pt
# ----------------------------------------
# File contains a HeteroData object.
# Node types: ['ip']
#   Node type 'ip':
#     Node features 'x': shape torch.Size([31, 1])
#     Number of nodes: 31
# Edge types: [('ip', 'network', 'ip'), ('ip', 'context', 'ip'), ('ip', 'knowledge', 'ip')]
#   Edge type ('ip', 'network', 'ip'):
#     Edge index: shape torch.Size([2, 26])
#     Edge attributes: shape torch.Size([26, 10])
#   Edge type ('ip', 'context', 'ip'):
#     Edge index: shape torch.Size([2, 26])
#     Edge attributes: shape torch.Size([26, 11])
#   Edge type ('ip', 'knowledge', 'ip'):
#     Edge index: shape torch.Size([2, 26])
#     Edge attributes: shape torch.Size([26, 17])
# ----------------------------------------

# %%
#was test for inside of graph ( no need to run)
import os
import networkx as nx

def inspect_community_in_gpickle(file_path):
    """
    Inspects the presence of the 'community' attribute in a .gpickle file.

    Parameters:
        file_path (str): Path to the .gpickle file.
    """
    print(f"Inspecting file: {file_path}")
    print("-" * 40)

    # Load the graph
    G = nx.read_gpickle(file_path)

    # Check for 'community' attribute in nodes
    if all('community' in G.nodes[node] for node in G.nodes()):
        print(f"All nodes have a 'community' attribute.")
        print("Sample 'community' values:")
        sample_communities = {node: G.nodes[node]['community'] for node in list(G.nodes)[:10]}
        print(sample_communities)
    else:
        missing = [node for node in G.nodes() if 'community' not in G.nodes[node]]
        print(f"Some nodes are missing the 'community' attribute. Missing nodes: {missing[:10]} (only showing first 10)")

    print(f"Total nodes: {len(G.nodes())}")
    print("-" * 40)


def inspect_all_gpickle_files(directory):
    """
    Inspects the 'community' attribute in all .gpickle files in a given directory.

    Parameters:
        directory (str): Path to the directory containing .gpickle files.
    """
    print(f"Inspecting .gpickle files in directory: {directory}")
    for file in os.listdir(directory):
        if file.endswith(".gpickle"):
            inspect_community_in_gpickle(os.path.join(directory, file))


# Directory containing your .gpickle files
input_graph_dir = "3ed_trai_h_graphs_commun"

# Inspect all files in the directory for the 'community' attribute
inspect_all_gpickle_files(input_graph_dir)
# Out:
# Inspecting .gpickle files in directory: 3ed_trai_h_graphs_commun
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1886.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'41.24.115.254': 0, '192.168.1.190': 0, '183.69.192.168': 1, '1.1.192.168': 1, '252.229.192.168': 2, '1.190.172.17': 2, '41.72.66.76': 3, '192.168.1.32': 3, '41.184.177.116': 4, '192.168.1.31': 4}
# Total nodes: 198
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'228.243.192.168': 0, '1.152.192.168': 0, '217.97.192.168': 0, '177.30.87.144': 1, '192.168.1.1': 1, '120.187.192.168': 2, '1.152.3.122': 2, '93.53.192.168': 0, '244.15.103.115': 3, '192.168.1.79': 3}
# Total nodes: 60
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1408.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'219.143.192.168': 0, '1.152.192.168': 0, '241.112.192.168': 1, '1.152.3.122': 1, '219.187.3.122': 2, '49.24.192.168': 2, '184.179.192.168': 0, '177.30.87.144': 3, '192.168.1.1': 3, '179.201.192.168': 0}
# Total nodes: 29
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2002.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '8.6.0.1': 2, '8.0.6.4': 2, '192.168.1.193': 3, '192.168.1.152': 4, '224.0.0.251': 4, '224.0.0.252': 1, '192.168.1.190': 5, '199.253.182.182': 5}
# Total nodes: 163
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1991.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '192.168.1.180': 2, '192.168.1.190': 3, '192.168.1.193': 4, '192.168.1.152': 3, '192.168.1.194': 1, '192.168.1.255': 1, '192.5.5.241': 3, '204.61.216.50': 3}
# Total nodes: 187
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1934.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'127.224.192.168': 0, '1.30.192.168': 0, '183.54.192.168': 1, '1.1.192.168': 1, '36.130.192.168': 2, '1.184.192.168': 2, '171.84.192.168': 0, '159.64.192.168': 2, '230.76.192.168': 0, '127.68.192.168': 2}
# Total nodes: 5820
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2014.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '239.255.255.250': 2, '224.0.0.251': 3, '224.0.0.252': 2, '192.168.1.193': 2, '192.168.1.190': 4, '203.119.86.101': 4, '192.168.1.180': 5, '192.168.1.194': 1}
# Total nodes: 88
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_671.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '244.15.103.115': 1, '192.168.1.79': 1, '22.4.192.168': 2, '1.152.192.168': 2, '41.168.58.218': 3, '192.168.1.195': 3, '179.177.145.115': 4, '192.168.1.193': 4}
# Total nodes: 18
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1414.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'244.15.103.115': 0, '192.168.1.79': 0, '177.30.87.144': 1, '192.168.1.1': 1, '180.36.3.122': 2, '49.24.192.168': 2, '73.24.192.168': 3, '1.152.192.168': 3, '79.228.192.168': 3, '156.192.192.168': 4}
# Total nodes: 30
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1994.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.1': 0, '192.168.1.195': 1, '40.90.189.152': 1, '192.168.1.193': 2, '192.168.1.152': 3, '192.168.1.194': 4, '192.168.1.255': 4, '8.6.0.1': 5, '8.0.6.4': 5, '224.0.0.252': 6}
# Total nodes: 105
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1986.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'34.230.157.88': 0, '192.168.1.33': 0, '192.168.1.37': 0, '192.168.1.193': 1, '224.0.0.252': 2, '192.168.1.180': 3, '129.250.35.250': 3, '27.124.125.251': 3, '129.250.35.251': 3, '203.122.222.157': 3}
# Total nodes: 274
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1895.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'182.175.192.168': 0, '1.1.192.168': 1, '205.253.192.168': 2, '1.195.224.0': 2, '244.15.103.115': 3, '192.168.1.79': 3, '4.49.57.84': 4, '192.168.1.169': 4, '38.81.192.168': 5, '1.43.192.168': 5}
# Total nodes: 286
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2019.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'104.244.37.20': 0, '192.168.1.31': 0, '8.6.0.1': 1, '8.0.6.4': 1, '192.168.1.152': 2, '192.168.1.195': 3, '239.255.255.250': 4, '104.193.19.59': 0, '192.229.237.25': 0, '151.101.24.134': 0}
# Total nodes: 510
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1921.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'182.141.192.168': 0, '1.184.192.168': 0, '244.15.192.168': 1, '1.195.192.168': 1, '242.48.192.168': 1, '240.153.192.168': 1, '236.249.192.168': 1, '181.161.192.168': 2, '1.1.192.168': 2, '182.173.192.168': 3}
# Total nodes: 94
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2008.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '40.90.190.179': 0, '192.168.1.190': 2, '91.189.91.139': 2, '224.0.0.252': 3, '224.0.0.251': 4, '192.168.1.180': 5, '203.119.86.101': 2, '239.255.255.250': 3}
# Total nodes: 83
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1409.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '186.191.192.168': 1, '1.152.3.122': 1, '113.206.192.168': 2, '1.152.192.168': 2, '8.251.192.168': 2, '183.132.192.168': 1, '5.121.192.168': 2, '178.160.192.168': 2}
# Total nodes: 36
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2005.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.1': 0, '192.168.1.195': 1, '192.168.1.169': 0, '239.255.255.250': 0, '192.168.1.193': 0, '40.90.190.179': 1, '192.168.1.180': 2, '203.122.222.157': 2, '224.0.0.22': 0, '224.0.0.251': 3}
# Total nodes: 76
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1402.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '46.79.192.168': 1, '1.152.3.122': 1, '228.62.3.122': 2, '49.24.192.168': 2, '70.114.192.168': 3, '1.152.192.168': 3, '35.248.192.168': 1, '35.37.192.168': 1}
# Total nodes: 27
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1987.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '192.168.1.180': 2, '192.168.1.190': 3, '203.119.86.101': 3, '224.0.0.252': 4, '239.255.255.250': 1, '192.168.1.79': 1, '192.168.1.193': 5, '202.158.214.106': 2}
# Total nodes: 567
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1998.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'8.6.0.1': 0, '8.0.6.4': 0, '192.168.1.1': 1, '192.168.1.195': 2, '192.168.1.133': 3, '224.0.0.251': 3, '192.168.1.193': 4, '192.168.1.152': 4, '239.255.255.250': 5, '224.0.0.252': 5}
# Total nodes: 110
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1965.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'176.28.50.165': 0, '192.168.1.36': 0, '192.168.1.152': 0, '192.168.1.195': 1, '192.168.1.32': 0, '8.6.0.1': 2, '8.0.6.4': 2, '192.168.1.180': 3, '61.68.38.238': 3, '52.28.231.150': 0}
# Total nodes: 176
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1929.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'41.185.201.54': 0, '192.168.1.195': 0, '159.113.192.168': 1, '1.184.192.168': 1, '250.4.192.168': 2, '1.30.192.168': 2, '8.63.52.59': 3, '177.21.192.168': 3, '183.58.192.168': 4, '1.1.192.168': 4}
# Total nodes: 2189
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1931.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'146.7.192.168': 0, '1.30.192.168': 0, '45.118.192.168': 0, '34.118.192.168': 0, '36.7.192.168': 0, '101.85.192.168': 0, '156.81.192.168': 0, '194.70.192.168': 0, '186.115.192.168': 0, '194.148.192.168': 0}
# Total nodes: 6058
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1404.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'202.201.192.168': 0, '1.152.192.168': 0, '195.141.192.168': 0, '189.14.192.168': 0, '181.78.192.168': 1, '1.152.3.122': 1, '187.167.192.168': 0, '126.38.3.122': 2, '49.24.192.168': 2, '173.29.192.168': 0}
# Total nodes: 28
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2000.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.1': 0, '192.168.1.195': 1, '192.168.1.180': 2, '103.76.40.123': 2, '192.168.1.193': 3, '192.168.1.152': 4, '224.0.0.252': 5, '224.0.0.251': 4, '192.168.1.190': 6, '203.119.86.101': 6}
# Total nodes: 87
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2012.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.1': 0, '192.168.1.195': 1, '224.0.0.252': 2, '239.255.255.250': 2, '192.168.1.190': 3, '203.119.86.101': 3, '192.168.1.180': 4, '192.168.1.193': 0, '40.90.190.179': 1, '203.122.222.157': 4}
# Total nodes: 63
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1881.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'26.76.192.168': 0, '1.31.192.168': 0, '122.34.172.17': 1, '0.5.192.168': 1, '177.30.87.144': 2, '192.168.1.1': 2, '196.17.192.168': 0, '27.19.192.168': 0, '41.40.114.209': 3, '192.168.1.152': 3}
# Total nodes: 344
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2020.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.193': 0, '239.255.255.250': 0, '192.168.1.180': 1, '192.0.32.59': 1, '192.168.1.190': 2, '192.0.32.252': 2, '192.168.1.6': 0, '95.101.36.128': 2, '192.168.1.195': 3, '52.139.250.253': 4}
# Total nodes: 245
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1888.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'183.73.192.168': 0, '1.1.192.168': 0, '49.59.192.168': 1, '1.190.172.17': 1, '223.8.172.17': 2, '0.7.192.168': 2, '222.251.172.17': 2, '16.189.192.168': 3, '1.152.192.168': 3, '183.69.192.168': 0}
# Total nodes: 165
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1883.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'182.19.172.17': 0, '0.7.192.168': 0, '143.131.172.17': 1, '0.5.192.168': 1, '143.71.172.17': 1, '41.72.66.76': 2, '192.168.1.32': 2, '196.153.192.168': 3, '1.190.172.17': 3, '41.24.115.254': 4}
# Total nodes: 194
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_656.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'132.211.192.168': 0, '1.152.192.168': 0, '41.238.224.122': 1, '192.168.1.190': 1, '133.81.192.168': 0, '249.83.3.122': 2, '49.24.192.168': 2, '131.123.192.168': 0, '128.183.192.168': 0, '127.246.192.168': 0}
# Total nodes: 54
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1412.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'27.234.192.168': 0, '1.152.3.122': 0, '177.30.87.144': 1, '192.168.1.1': 1, '24.211.192.168': 0, '248.67.192.168': 2, '1.152.192.168': 2, '37.14.3.122': 3, '49.24.192.168': 3, '72.46.192.168': 2}
# Total nodes: 22
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1925.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'90.180.192.168': 0, '1.34.52.59': 0, '182.149.192.168': 1, '1.184.192.168': 1, '135.97.192.168': 2, '1.30.18.184': 2, '182.148.192.168': 1, '155.57.192.168': 2, '182.180.192.168': 3, '1.152.192.168': 3}
# Total nodes: 232
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1875.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '183.71.192.168': 1, '1.1.192.168': 1, '183.74.192.168': 1, '183.73.192.168': 1, '183.69.192.168': 1, '201.154.192.168': 2, '1.30.192.168': 2, '41.72.66.76': 3}
# Total nodes: 125
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1910.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'75.209.192.168': 0, '1.30.35.156': 0, '177.30.87.144': 1, '192.168.1.1': 1, '41.219.29.220': 2, '192.168.1.184': 2, '183.44.192.168': 3, '1.1.192.168': 3, '246.2.192.168': 4, '1.190.192.168': 4}
# Total nodes: 206
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1909.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'246.78.192.168': 0, '1.152.192.168': 0, '76.159.192.168': 1, '1.39.192.168': 1, '246.2.192.168': 2, '1.190.192.168': 2, '41.24.115.254': 3, '192.168.1.190': 3, '239.158.192.168': 4, '1.30.192.168': 4}
# Total nodes: 159
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1908.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'246.14.192.168': 0, '1.184.192.168': 0, '91.52.192.168': 1, '1.39.18.195': 1, '183.74.192.168': 2, '1.1.192.168': 2, '76.159.192.168': 3, '1.39.192.168': 3, '75.209.192.168': 4, '1.30.35.156': 4}
# Total nodes: 184
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2001.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.1': 0, '192.168.1.195': 1, '8.6.0.1': 2, '8.0.6.4': 2, '192.168.1.193': 3, '192.168.1.152': 4, '224.0.0.22': 5, '224.0.0.252': 5, '239.255.255.250': 5, '192.168.1.180': 6}
# Total nodes: 136
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1913.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'244.15.103.115': 0, '192.168.1.79': 0, '246.14.192.168': 1, '1.184.192.168': 1, '239.162.192.168': 2, '1.30.192.168': 2, '239.168.192.168': 2, '76.159.192.168': 3, '1.39.192.168': 3, '41.91.115.91': 4}
# Total nodes: 177
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1889.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'183.70.192.168': 0, '1.1.192.168': 0, '183.74.192.168': 0, '80.66.172.17': 1, '0.5.192.168': 1, '181.161.192.168': 0, '181.97.192.168': 0, '46.54.172.17': 1, '46.43.172.17': 1, '52.71.192.168': 2}
# Total nodes: 18
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2006.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '40.90.190.179': 0, '224.0.0.252': 2, '224.0.0.251': 3, '224.0.0.22': 2, '192.168.1.180': 4, '192.168.1.190': 1, '199.253.182.182': 1, '239.255.255.250': 2}
# Total nodes: 98
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1995.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'8.6.0.1': 0, '8.0.6.4': 0, '192.168.1.195': 1, '192.168.1.1': 2, '239.255.255.250': 2, '192.168.1.193': 3, '192.168.1.152': 4, '192.168.1.190': 5, '208.84.2.53': 5, '192.168.1.180': 6}
# Total nodes: 117
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1890.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'78.209.192.168': 0, '1.32.192.168': 0, '122.133.192.168': 1, '1.31.192.168': 1, '122.73.192.168': 1, '106.58.192.168': 2, '1.190.192.168': 2, '182.158.192.168': 2, '1.194.192.168': 3, '182.199.192.168': 4}
# Total nodes: 16606
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_660.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0}
# Total nodes: 2
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_0.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '244.15.103.115': 1, '192.168.1.79': 1, '41.238.224.122': 2, '192.168.1.190': 2}
# Total nodes: 6
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1919.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'182.137.192.168': 0, '1.190.192.168': 0, '167.46.176.28': 1, '50.165.192.168': 1, '182.175.192.168': 2, '1.152.192.168': 2, '218.155.52.59': 3, '177.21.192.168': 3, '230.158.52.59': 3, '191.134.52.59': 3}
# Total nodes: 298
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2010.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '192.168.1.190': 2, '198.41.0.4': 2, '193.108.88.128': 2, '8.8.8.8': 0, '52.114.7.37': 0, '192.33.14.30': 2, '192.168.1.193': 1, '239.255.255.250': 1}
# Total nodes: 126
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1920.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'16.29.192.168': 0, '1.184.192.168': 0, '130.30.192.168': 1, '1.33.192.168': 1, '63.200.192.168': 1, '118.62.192.168': 0, '118.61.192.168': 0, '182.178.192.168': 2, '1.152.192.168': 2, '182.140.192.168': 3}
# Total nodes: 215
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1967.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.152': 0, '192.168.1.35': 0, '176.28.50.165': 0, '18.194.169.124': 0, '192.168.1.39': 0, '52.28.231.150': 0, '192.168.1.1': 1, '192.168.1.169': 1, '224.0.0.252': 1, '192.168.1.195': 2}
# Total nodes: 125
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_659.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '25.172.192.168': 1, '1.152.192.168': 1, '175.121.192.168': 2, '1.152.3.122': 2, '22.160.192.168': 1, '172.207.192.168': 2, '15.18.192.168': 1, '11.113.192.168': 1}
# Total nodes: 31
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1933.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'145.47.192.168': 0, '1.30.192.168': 0, '180.28.192.168': 0, '146.116.192.168': 1, '1.31.192.168': 1, '10.6.192.168': 1, '96.255.192.168': 0, '233.197.192.168': 0, '196.22.192.168': 2, '1.184.192.168': 2}
# Total nodes: 5980
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1937.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'241.232.192.168': 0, '1.184.192.168': 0, '122.155.192.168': 0, '107.150.192.168': 1, '1.30.192.168': 1, '61.43.192.168': 1, '234.33.192.168': 1, '216.113.192.168': 1, '224.212.192.168': 2, '1.31.192.168': 2}
# Total nodes: 4006
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_4.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'100.176.192.168': 0, '1.152.192.168': 0, '230.97.192.168': 0, '176.40.3.122': 1, '49.24.192.168': 1, '206.145.192.168': 2, '1.192.192.168': 2, '98.45.192.168': 0, '229.242.192.168': 0, '177.30.87.144': 3}
# Total nodes: 48
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1411.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'113.230.192.168': 0, '1.152.192.168': 0, '230.23.192.168': 0, '177.30.87.144': 1, '192.168.1.1': 1, '229.45.192.168': 0, '112.246.192.168': 0, '226.137.192.168': 0, '227.21.192.168': 0, '81.91.192.168': 0}
# Total nodes: 35
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1935.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'38.82.192.168': 0, '1.31.192.168': 0, '149.97.192.168': 0, '38.89.192.168': 0, '7.140.192.168': 0, '6.139.192.168': 1, '1.184.192.168': 1, '128.40.192.168': 1, '148.217.192.168': 2, '1.30.192.168': 2}
# Total nodes: 5465
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_658.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '119.221.192.168': 1, '1.152.192.168': 1, '159.236.3.122': 2, '49.24.192.168': 2, '230.113.192.168': 3, '1.152.3.122': 3, '179.177.145.115': 4, '192.168.1.193': 4}
# Total nodes: 32
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1930.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'66.142.192.168': 0, '1.31.192.168': 0, '187.51.192.168': 1, '1.30.192.168': 1, '41.26.39.127': 2, '192.168.1.194': 2, '240.162.192.168': 3, '1.184.192.168': 3, '139.78.192.168': 0, '217.132.192.168': 1}
# Total nodes: 4918
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1932.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'96.16.192.168': 0, '1.30.192.168': 0, '177.30.87.144': 1, '192.168.1.1': 1, '182.148.192.168': 2, '1.184.192.168': 2, '187.4.192.168': 2, '186.186.192.168': 0, '11.95.192.168': 0, '20.239.192.168': 2}
# Total nodes: 5648
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1880.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'181.87.192.168': 0, '1.1.192.168': 0, '226.52.172.17': 1, '0.8.192.168': 1, '93.74.192.168': 2, '1.31.192.168': 2, '117.2.192.168': 2, '166.147.192.168': 2, '170.177.192.168': 2, '183.69.192.168': 0}
# Total nodes: 1209
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1963.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.190': 0, '192.168.1.32': 1, '192.168.1.152': 2, '192.168.1.36': 1, '192.168.1.195': 3, '8.6.0.1': 4, '8.0.6.4': 4, '192.168.1.1': 1, '176.28.50.165': 1, '52.28.231.150': 1}
# Total nodes: 208
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2004.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '224.0.0.251': 2, '224.0.0.252': 3, '239.255.255.250': 3, '192.168.1.180': 4, '192.168.1.190': 5, '203.119.86.101': 5, '192.168.1.193': 1, '40.90.190.179': 0}
# Total nodes: 94
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1905.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'246.14.192.168': 0, '1.184.192.168': 0, '246.78.192.168': 1, '1.152.192.168': 1, '239.159.192.168': 2, '1.30.192.168': 2, '168.199.192.168': 3, '1.39.35.156': 3, '76.150.192.168': 4, '1.39.192.168': 4}
# Total nodes: 263
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_674.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'244.15.103.115': 0, '192.168.1.79': 0, '97.255.192.168': 1, '1.152.192.168': 1, '177.30.87.144': 2, '192.168.1.1': 2, '92.204.192.168': 1, '129.200.3.122': 3, '49.24.192.168': 3, '129.149.3.122': 3}
# Total nodes: 34
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1928.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'18.153.192.168': 0, '1.31.192.168': 0, '181.233.192.168': 0, '182.180.192.168': 1, '1.152.192.168': 1, '182.148.192.168': 2, '1.184.192.168': 2, '72.142.192.168': 3, '1.30.192.168': 3, '150.226.192.168': 2}
# Total nodes: 2251
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1887.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'31.196.192.168': 0, '1.190.172.17': 0, '30.18.192.168': 0, '41.72.66.76': 1, '192.168.1.32': 1, '177.30.87.144': 2, '192.168.1.1': 2, '41.184.177.116': 3, '192.168.1.31': 3, '237.238.172.17': 4}
# Total nodes: 159
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1894.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'183.70.192.168': 0, '1.1.192.168': 0, '41.40.114.209': 1, '192.168.1.152': 1, '182.150.192.168': 2, '1.194.192.168': 2, '1.31.192.168': 2, '182.158.192.168': 3, '93.16.23.225': 4, '192.168.1.194': 4}
# Total nodes: 16617
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2016.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.1': 0, '192.168.1.195': 1, '224.0.0.22': 2, '224.0.0.252': 2, '239.255.255.250': 2, '224.0.0.251': 1, '192.168.1.193': 3, '192.168.1.180': 4, '192.168.1.190': 5, '203.119.86.101': 5}
# Total nodes: 131
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_3.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'158.218.192.168': 0, '1.152.192.168': 0, '158.117.192.168': 0, '74.191.192.168': 1, '1.152.3.122': 1, '155.18.192.168': 0, '152.41.192.168': 0, '168.78.192.168': 0, '71.38.192.168': 1, '41.238.224.122': 2}
# Total nodes: 75
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2009.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '40.90.190.179': 0, '224.0.0.251': 2, '224.0.0.252': 3, '224.0.0.22': 3, '192.168.1.190': 4, '203.119.86.101': 4, '239.255.255.250': 3, '192.168.1.180': 5}
# Total nodes: 65
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1405.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '93.139.3.122': 1, '49.24.192.168': 1, '89.128.3.122': 1, '134.245.192.168': 2, '1.152.3.122': 2, '99.132.192.168': 3, '1.152.192.168': 3, '133.208.192.168': 2}
# Total nodes: 29
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1942.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'97.55.192.168': 0, '1.34.192.168': 0, '4.42.192.168': 1, '1.152.192.168': 1, '182.177.192.168': 1, '154.124.192.168': 0, '98.73.192.168': 0, '4.106.192.168': 1, '182.139.192.168': 2, '1.190.192.168': 2}
# Total nodes: 351
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1877.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'179.196.192.168': 0, '1.32.192.168': 0, '237.219.192.168': 1, '1.31.192.168': 2, '122.106.192.168': 0, '16.0.192.168': 0, '84.175.192.168': 0, '253.221.192.168': 2, '43.122.192.168': 0, '205.29.192.168': 2}
# Total nodes: 22128
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1893.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'181.153.192.168': 0, '1.1.192.168': 0, '182.187.192.168': 0, '84.203.192.168': 1, '1.180.192.168': 1, '133.231.192.168': 2, '1.30.192.168': 2, '54.208.192.168': 3, '1.32.192.168': 3, '144.75.192.168': 3}
# Total nodes: 1438
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1966.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'52.28.231.150': 0, '192.168.1.39': 0, '192.168.1.184': 0, '192.168.1.35': 0, '176.28.50.165': 0, '18.194.169.124': 0, '192.168.1.152': 0, '192.168.1.1': 0, '192.168.1.195': 1, '192.168.1.190': 2}
# Total nodes: 163
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '244.15.103.115': 1, '192.168.1.79': 1, '164.91.192.168': 2, '1.152.3.122': 2, '164.42.192.168': 2, '161.241.192.168': 2, '161.130.192.168': 2, '140.85.192.168': 3}
# Total nodes: 36
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_676.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '255.238.3.122': 1, '49.24.192.168': 1, '225.71.192.168': 2, '1.152.192.168': 2, '108.129.192.168': 3, '1.152.3.122': 3, '212.213.192.168': 2, '93.125.192.168': 3}
# Total nodes: 33
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1882.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'182.175.192.168': 0, '1.1.192.168': 0, '4.49.57.84': 1, '192.168.1.169': 1, '41.184.177.116': 2, '192.168.1.31': 2, '183.69.192.168': 0, '41.24.115.254': 3, '192.168.1.190': 3, '121.66.172.17': 4}
# Total nodes: 216
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1907.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'76.191.192.168': 0, '1.39.192.168': 0, '182.159.192.168': 1, '1.194.192.168': 1, '41.26.39.127': 2, '192.168.1.194': 2, '76.153.192.168': 0, '239.162.192.168': 3, '1.30.192.168': 3, '41.219.29.220': 4}
# Total nodes: 147
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1912.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'244.15.103.115': 0, '192.168.1.79': 0, '75.209.192.168': 1, '1.30.35.156': 1, '183.29.192.168': 2, '1.1.192.168': 2, '91.52.192.168': 3, '1.39.18.195': 3, '181.97.192.168': 2, '35.108.192.168': 4}
# Total nodes: 199
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1885.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'41.184.177.116': 0, '192.168.1.31': 0, '177.30.87.144': 1, '192.168.1.1': 1, '41.24.115.254': 2, '192.168.1.190': 2, '125.55.172.17': 3, '0.5.192.168': 3, '184.49.172.17': 4, '0.7.192.168': 4}
# Total nodes: 163
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1918.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'230.158.52.59': 0, '177.21.192.168': 0, '183.41.192.168': 1, '1.1.192.168': 1, '183.72.192.168': 1, '183.68.192.168': 1, '167.49.176.28': 2, '50.165.192.168': 2, '177.30.87.144': 3, '192.168.1.1': 3}
# Total nodes: 130
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_673.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'244.15.103.115': 0, '192.168.1.79': 0, '177.30.87.144': 1, '192.168.1.1': 1, '31.151.192.168': 2, '1.152.3.122': 2, '30.55.192.168': 2, '197.177.3.122': 3, '49.24.192.168': 3, '226.219.192.168': 4}
# Total nodes: 39
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1938.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'172.252.192.168': 0, '1.30.192.168': 0, '77.227.192.168': 0, '149.223.192.168': 1, '1.184.192.168': 1, '41.26.39.127': 2, '192.168.1.194': 2, '41.184.177.116': 3, '192.168.1.31': 3, '214.62.192.168': 0}
# Total nodes: 2373
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1939.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'145.2.192.168': 0, '1.38.192.168': 0, '14.212.192.168': 0, '228.149.192.168': 0, '196.153.192.168': 1, '1.36.192.168': 1, '229.241.192.168': 0, '165.11.192.168': 0, '149.79.192.168': 0, '82.101.192.168': 0}
# Total nodes: 3236
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1410.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '129.32.192.168': 1, '1.152.3.122': 1, '144.114.192.168': 2, '1.152.192.168': 2, '172.79.192.168': 2, '35.131.192.168': 2, '120.125.3.122': 3, '49.24.192.168': 3}
# Total nodes: 24
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_655.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'5.204.192.168': 0, '1.152.192.168': 0, '179.177.145.115': 1, '192.168.1.193': 1, '177.30.87.144': 2, '192.168.1.1': 2, '112.117.192.168': 0, '252.225.192.168': 0, '133.79.192.168': 3, '1.152.3.122': 3}
# Total nodes: 142
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1996.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.1': 0, '192.168.1.195': 1, '192.168.1.190': 2, '192.58.128.30': 2, '193.108.88.128': 2, '52.114.128.9': 1, '192.55.83.30': 2, '8.8.8.8': 3, '192.168.1.193': 3, '192.168.1.152': 4}
# Total nodes: 175
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1936.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'80.191.192.168': 0, '1.30.192.168': 0, '54.70.192.168': 0, '181.18.192.168': 0, '54.77.192.168': 0, '123.186.192.168': 0, '182.149.192.168': 1, '1.184.192.168': 1, '30.185.192.168': 0, '54.152.192.168': 2}
# Total nodes: 6383
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2013.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '192.168.1.180': 2, '144.48.166.166': 2, '192.168.1.194': 1, '192.168.1.255': 1, '103.214.220.220': 2, '224.0.0.251': 3, '224.0.0.252': 4, '224.0.0.22': 4}
# Total nodes: 120
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1940.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'157.8.192.168': 0, '1.38.192.168': 0, '151.237.192.168': 0, '154.25.192.168': 0, '151.59.192.168': 0, '2.99.192.168': 0, '33.120.192.168': 0, '4.242.192.168': 0, '197.243.192.168': 0, '38.37.192.168': 0}
# Total nodes: 4496
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1992.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '192.168.1.193': 2, '239.255.255.250': 1, '40.90.189.152': 0, '8.6.0.1': 3, '8.0.6.4': 3, '192.168.1.79': 1, '192.168.1.152': 4, '192.168.1.17': 1}
# Total nodes: 199
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_654.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'184.32.192.168': 0, '1.152.3.122': 0, '179.177.145.115': 1, '192.168.1.193': 1, '192.168.1.192': 1, '192.168.1.194': 1, '183.76.192.168': 0, '177.30.87.144': 2, '192.168.1.1': 2, '210.11.192.168': 3}
# Total nodes: 93
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_672.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'12.238.192.168': 0, '1.152.192.168': 0, '244.15.103.115': 1, '192.168.1.79': 1, '103.130.192.168': 2, '1.152.3.122': 2, '101.176.192.168': 2, '10.170.192.168': 0, '230.242.192.168': 0, '179.177.145.115': 3}
# Total nodes: 38
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1400.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'244.87.192.168': 0, '1.152.192.168': 0, '60.211.3.122': 1, '49.24.192.168': 1, '210.231.192.168': 0, '242.39.192.168': 0, '203.115.192.168': 0, '204.74.192.168': 0, '143.47.192.168': 2, '1.152.3.122': 2}
# Total nodes: 28
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1926.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'90.180.192.168': 0, '1.34.52.59': 0, '211.97.192.168': 1, '1.30.18.184': 1, '157.20.192.168': 1, '208.46.192.168': 2, '1.184.119.104': 2, '134.90.192.168': 1, '255.36.192.168': 3, '1.184.192.168': 3}
# Total nodes: 2047
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1990.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.193': 0, '192.168.1.152': 1, '192.168.1.1': 2, '192.168.1.195': 3, '192.168.1.190': 1, '205.251.192.206': 1, '96.7.49.66': 1, '192.58.128.30': 1, '205.251.192.27': 1, '192.31.80.30': 1}
# Total nodes: 552
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1906.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'245.250.192.168': 0, '1.194.192.168': 0, '246.78.192.168': 1, '1.152.192.168': 1, '239.168.192.168': 2, '1.30.192.168': 2, '207.71.192.168': 3, '1.30.176.28': 3, '246.2.192.168': 4, '1.190.192.168': 4}
# Total nodes: 181
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1911.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'76.153.192.168': 0, '1.39.192.168': 0, '167.72.176.28': 1, '50.165.192.168': 1, '183.43.192.168': 2, '1.1.192.168': 2, '183.29.192.168': 2, '183.75.192.168': 2, '239.157.192.168': 3, '1.30.192.168': 3}
# Total nodes: 204
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1988.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '192.168.1.193': 2, '192.168.1.37': 2, '192.168.1.33': 2, '239.255.255.250': 1, '224.0.0.252': 1, '192.168.1.190': 3, '224.0.0.251': 1, '192.168.1.169': 1}
# Total nodes: 478
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1968.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'52.28.231.150': 0, '192.168.1.35': 0, '18.194.169.124': 0, '192.168.1.39': 0, '192.168.1.195': 1, '192.168.1.6': 2, '239.255.255.250': 3, '224.0.0.252': 3, '192.168.1.1': 3, '192.168.1.152': 0}
# Total nodes: 99
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1879.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'94.238.192.168': 0, '1.193.192.168': 0, '151.83.192.168': 1, '1.195.224.0': 1, '81.54.192.168': 1, '94.35.192.168': 0, '183.103.192.168': 2, '1.32.192.168': 2, '62.251.192.168': 2, '12.241.192.168': 2}
# Total nodes: 16743
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1398.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '41.168.58.218': 1, '192.168.1.195': 1, '89.179.192.168': 2, '1.152.192.168': 2, '84.249.192.168': 2, '46.150.192.168': 2, '130.19.3.122': 3, '49.24.192.168': 3}
# Total nodes: 31
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1878.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'41.185.201.54': 0, '192.168.1.195': 0, '197.165.192.229': 1, '232.240.192.168': 1, '197.73.192.229': 1, '198.172.192.229': 1, '91.47.192.168': 2, '1.195.192.229': 2, '83.142.192.168': 3, '1.195.224.0': 3}
# Total nodes: 344
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1876.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'181.161.192.168': 0, '1.1.192.168': 0, '41.24.115.254': 1, '192.168.1.190': 1, '144.119.192.168': 2, '1.152.192.168': 2, '41.72.66.76': 3, '192.168.1.32': 3, '231.20.95.59': 4, '192.168.1.49': 4}
# Total nodes: 17604
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2003.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '192.168.1.193': 2, '192.168.1.152': 3, '224.0.0.22': 4, '224.0.0.251': 3, '224.0.0.252': 4, '192.168.1.190': 5, '203.119.86.101': 5, '192.168.1.180': 6}
# Total nodes: 129
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1993.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '192.168.1.193': 2, '192.168.1.152': 3, '224.0.0.252': 4, '239.255.255.250': 4, '8.6.0.1': 5, '8.0.6.4': 5, '192.168.1.180': 6, '103.214.220.220': 6}
# Total nodes: 130
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_657.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '28.27.192.168': 1, '1.152.3.122': 1, '26.17.192.168': 1, '201.78.3.122': 2, '49.24.192.168': 2, '199.142.3.122': 2, '163.209.192.168': 3, '1.152.192.168': 3}
# Total nodes: 32
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2021.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'157.48.192.168': 0, '1.169.192.168': 0, '182.187.192.168': 0, '1.1.192.168': 0, '156.134.192.168': 0, '163.23.192.168': 0, '155.83.192.168': 0, '170.206.192.168': 0, '169.202.192.168': 0, '169.12.192.168': 0}
# Total nodes: 137853
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1891.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'129.201.192.168': 0, '1.31.192.168': 0, '128.37.192.168': 0, '226.147.192.168': 1, '1.195.192.168': 1, '80.172.192.168': 2, '1.79.192.168': 2, '181.161.192.168': 3, '1.1.192.168': 3, '166.189.192.168': 0}
# Total nodes: 2176
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1927.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'30.28.192.168': 0, '1.31.52.59': 0, '32.106.192.168': 0, '130.211.192.168': 0, '100.199.192.168': 0, '182.142.192.168': 1, '1.190.192.168': 1, '87.222.192.168': 0, '130.205.192.168': 0, '168.228.192.168': 0}
# Total nodes: 3280
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_675.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'244.15.103.115': 0, '192.168.1.79': 0, '177.30.87.144': 1, '192.168.1.1': 1, '170.102.192.168': 2, '1.152.3.122': 2, '29.233.192.168': 3, '1.152.192.168': 3, '28.20.192.168': 3, '28.145.192.168': 3}
# Total nodes: 33
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1413.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'244.15.103.115': 0, '192.168.1.79': 0, '159.120.192.168': 1, '1.152.192.168': 1, '83.160.192.168': 1, '177.30.87.144': 2, '192.168.1.1': 2, '214.6.192.168': 3, '1.152.3.122': 3, '229.239.3.122': 4}
# Total nodes: 27
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1406.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'73.246.192.168': 0, '1.152.192.168': 0, '52.43.3.122': 1, '49.24.192.168': 1, '51.51.3.122': 1, '22.143.192.168': 0, '82.214.192.168': 2, '1.152.3.122': 2, '58.112.192.168': 0, '5.52.192.168': 0}
# Total nodes: 30
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1397.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'177.30.87.144': 0, '192.168.1.1': 0, '48.177.192.168': 1, '1.152.3.122': 1, '234.124.192.168': 2, '1.152.192.168': 2, '44.10.192.168': 1, '183.107.3.122': 3, '49.24.192.168': 3, '39.161.192.168': 1}
# Total nodes: 25
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1399.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'23.24.192.168': 0, '1.152.192.168': 0, '66.243.192.168': 0, '21.200.192.168': 0, '199.62.192.168': 1, '1.152.3.122': 1, '198.97.192.168': 1, '19.222.192.168': 0, '197.29.192.168': 1, '57.218.192.168': 0}
# Total nodes: 43
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1997.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.190': 0, '192.5.5.241': 0, '91.189.95.3': 0, '192.168.1.152': 1, '224.0.0.251': 2, '192.26.92.30': 0, '192.168.1.195': 3, '40.90.189.152': 3, '192.168.1.193': 1, '8.6.0.1': 4}
# Total nodes: 138
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2015.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.1': 0, '192.168.1.195': 1, '192.168.1.193': 0, '239.255.255.250': 0, '224.0.0.252': 0, '192.168.1.190': 2, '203.119.86.101': 2, '192.168.1.180': 3, '103.76.40.123': 3, '193.108.88.128': 2}
# Total nodes: 107
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_653.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'34.209.192.168': 0, '1.152.192.168': 0, '171.142.192.168': 0, '231.191.192.168': 1, '1.152.3.122': 1, '29.95.192.168': 0, '177.30.87.144': 2, '192.168.1.1': 2, '18.127.192.168': 0, '14.112.192.168': 0}
# Total nodes: 46
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1407.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'250.250.192.168': 0, '1.152.192.168': 0, '31.224.192.168': 1, '1.152.3.122': 1, '177.30.87.144': 2, '192.168.1.1': 2, '29.87.192.168': 1, '247.13.192.168': 0, '243.219.192.168': 0, '169.213.192.168': 0}
# Total nodes: 27
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1892.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'4.49.57.84': 0, '192.168.1.169': 0, '183.73.192.168': 1, '1.1.192.168': 1, '112.193.172.17': 2, '0.5.192.168': 2, '177.30.87.144': 3, '192.168.1.1': 3, '233.55.192.168': 4, '1.32.192.168': 4}
# Total nodes: 3010
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1999.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.1': 0, '192.168.1.195': 1, '192.168.1.193': 2, '192.168.1.152': 3, '224.0.0.252': 4, '192.168.1.190': 5, '203.119.86.101': 5, '192.168.1.180': 6, '239.255.255.250': 4, '40.90.189.152': 1}
# Total nodes: 114
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1403.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'242.224.192.168': 0, '1.152.3.122': 0, '239.144.192.168': 0, '239.76.192.168': 0, '173.55.3.122': 1, '49.24.192.168': 1, '234.125.192.168': 0, '11.228.192.168': 2, '1.152.192.168': 2, '126.136.192.168': 2}
# Total nodes: 33
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1896.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'49.69.192.168': 0, '1.31.192.168': 0, '49.233.192.168': 0, '107.14.192.168': 1, '1.169.192.168': 2, '7.141.192.168': 0, '200.172.192.168': 0, '107.24.192.168': 2, '221.97.192.168': 0, '226.203.192.168': 0}
# Total nodes: 15635
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1884.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'41.184.177.116': 0, '192.168.1.31': 0, '183.69.192.168': 1, '1.1.192.168': 1, '41.72.66.76': 2, '192.168.1.32': 2, '231.93.192.168': 3, '1.190.172.17': 3, '136.194.172.17': 4, '0.7.192.168': 4}
# Total nodes: 192
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1964.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.190': 0, '192.168.1.32': 1, '192.168.1.195': 2, '224.0.0.251': 3, '224.0.0.252': 4, '239.255.255.250': 4, '192.168.1.1': 1, '192.168.1.79': 4, '192.168.1.193': 5, '192.168.1.152': 1}
# Total nodes: 209
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2007.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '8.6.0.1': 2, '8.0.6.4': 2, '224.0.0.252': 3, '239.255.255.250': 3, '192.168.1.193': 1, '192.168.1.180': 4, '192.168.1.190': 5, '200.7.86.53': 5}
# Total nodes: 88
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_2011.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.195': 0, '192.168.1.1': 1, '8.6.0.1': 2, '8.0.6.4': 2, '40.90.190.179': 0, '224.0.0.252': 3, '192.168.1.180': 4, '192.168.1.190': 5, '239.255.255.250': 3, '224.0.0.22': 3}
# Total nodes: 112
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1401.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'142.98.192.168': 0, '1.152.192.168': 0, '177.30.87.144': 1, '192.168.1.1': 1, '140.93.192.168': 0, '135.141.192.168': 0, '91.149.192.168': 2, '1.152.3.122': 2, '11.127.3.122': 3, '49.24.192.168': 3}
# Total nodes: 35
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1941.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'144.188.192.168': 0, '1.38.192.168': 0, '176.246.192.168': 0, '30.150.192.168': 0, '178.116.192.168': 0, '214.32.192.168': 0, '184.220.192.168': 0, '103.233.192.168': 0, '182.131.192.168': 1, '1.194.192.168': 1}
# Total nodes: 2730
# ----------------------------------------
# Inspecting file: 3ed_trai_h_graphs_commun/graph_hour_1989.gpickle
# ----------------------------------------
# All nodes have a 'community' attribute.
# Sample 'community' values:
# {'192.168.1.1': 0, '192.168.1.195': 1, '192.168.1.180': 2, '203.59.7.250': 2, '103.214.220.220': 2, '192.168.1.190': 3, '205.251.199.194': 3, '193.108.91.240': 3, '184.84.165.134': 3, '239.255.255.250': 0}
# Total nodes: 145
# ----------------------------------------
